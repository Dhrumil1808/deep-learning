# %%
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import time

n_epochs = 10
batch_size = 128
nb_classes = 10

# Step 1: Read in data
mnist = input_data.read_data_sets('MNIST_data/', one_hot=True) 
# Step 2
nb_classes = 10# MNIST data image of shape 28 * 28 = 784
X = tf.placeholder(tf.float32, [None, 784])# 0 -9 digits recognition = 10 classes
Y = tf.placeholder(tf.float32, [None, nb_classes])


# Step 3
W = tf.Variable(tf.random_normal([784, nb_classes]))
b = tf.Variable(tf.random_normal([nb_classes]))


# Step 4
logits = tf.matmul(X, W) + b
hypothesis = tf.nn.softmax(tf.matmul(X, W) + b)
cost = tf.reduce_mean(-tf.reduce_sum(Y * tf.log(hypothesis), axis=1))


# Step 5:

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

#is_correct = tf.equal(tf.arg_max(hypothesis, 1), tf.arg_max(Y, 1))

# Step 6:

# Calculate accuracy
accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))


training_epochs = 15
batch_size = 100

with tf.Session() as sess:
    start_time = time.time()
    sess.run(tf.global_variables_initializer())	
    n_batches = int(mnist.train.num_examples/batch_size)
    for i in range(n_epochs): 
        total_loss = 0

        for _ in range(n_batches):
            X_batch, Y_batch = mnist.train.next_batch(batch_size)
            # Run the optimizer and loss, store the loss value as loss_batch
            
            loss_batch, _ = sess.run([cost, optimizer], feed_dict={X: X_batch, Y: Y_batch})
            total_loss += loss_batch
            #avg_cost += loss_batch / total_batch
        print('Average loss epoch {0}: {1}'.format(i, total_loss/n_batches))

    print('Total time: {0} seconds'.format(time.time() - start_time))


    # test the model
    preds = tf.nn.softmax(logits)
    correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(Y, 1))
    accuracy = tf.reduce_sum(tf.cast(correct_preds, tf.float32)) 
    
    n_batches = int(mnist.test.num_examples/batch_size)
    total_correct_preds = 0
    
    for i in range(n_batches):
        X_batch, Y_batch = mnist.test.next_batch(batch_size)
        accuracy_batch = sess.run([accuracy], feed_dict={X: X_batch, Y:Y_batch}) 
        total_correct_preds += sum(accuracy_batch)
        
    print('Accuracy {0}'.format(accuracy_batch))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Average loss epoch 0: 2.81390650522
# Average loss epoch 1: 1.14763376166
# Average loss epoch 2: 0.895900563543
# Average loss epoch 3: 0.774157944863
# Average loss epoch 4: 0.699344235984
# Average loss epoch 5: 0.646970804009
# Average loss epoch 6: 0.60755643254
# Average loss epoch 7: 0.577248574793
# Average loss epoch 8: 0.551418731172
# Average loss epoch 9: 0.530671231164
# Average loss epoch 10: 0.51345413292
# Average loss epoch 11: 0.497683128227
# Average loss epoch 12: 0.484917549789
# Average loss epoch 13: 0.472589892447
# Average loss epoch 14: 0.462097753842
# Average loss epoch 15: 0.453049917993
# Average loss epoch 16: 0.444168315516
# Average loss epoch 17: 0.436002210297
# Average loss epoch 18: 0.429127913497
# Average loss epoch 19: 0.422618750469
# Average loss epoch 20: 0.416700331311
# Average loss epoch 21: 0.411040605659
# Average loss epoch 22: 0.405467819937
# Average loss epoch 23: 0.400440205999
# Average loss epoch 24: 0.395852669288
# Average loss epoch 25: 0.391684785986
# Average loss epoch 26: 0.387454226261
# Average loss epoch 27: 0.383555628197
# Average loss epoch 28: 0.379729991325
# Average loss epoch 29: 0.376333973381
# Average loss epoch 30: 0.372969968454
# Average loss epoch 31: 0.369916970649
# Average loss epoch 32: 0.366373044239
# Average loss epoch 33: 0.363717142167
# Average loss epoch 34: 0.360827443451
# Average loss epoch 35: 0.358246292377
# Average loss epoch 36: 0.355507602637
# Average loss epoch 37: 0.353206375038
# Average loss epoch 38: 0.350931794826
# Average loss epoch 39: 0.348718456639
# Average loss epoch 40: 0.346427540779
# Average loss epoch 41: 0.343896612288
# Average loss epoch 42: 0.342308292511
# Average loss epoch 43: 0.3401819412
# Average loss epoch 44: 0.338273213445
# Average loss epoch 45: 0.336216849766
# Average loss epoch 46: 0.334490150146
# Average loss epoch 47: 0.332881038541
# Average loss epoch 48: 0.331121051217
# Average loss epoch 49: 0.329530752247
# Total time: 34.0720908642 seconds
# Accuracy [96.0]
